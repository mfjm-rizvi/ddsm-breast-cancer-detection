# %% [markdown]
# <a href="https://colab.research.google.com/github/mfjm-rizvi/ddsm-breast-cancer-detection/blob/main/01_dataset_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Breast Cancer Detection

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %% [markdown]
# ### Dataset

# %% [markdown]
# ### MIL

# %% [markdown]
# ## Baseline Model (EfficientNet-B0)

# %% [markdown]
# ### Training

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###
